# %%
print('Hello World')
# Out:
# Hello World

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_clean= pd.read_csv('../data/cleaned/cleaned_results.csv')

# %%
print("my" " " "name" " " "is" " " "Benta")
# Out:
# my name is Benta

# %%
print(f"my name is Benta")
# Out:
# my name is Benta

# %%
df_clean.head()
# Out:
#    Unnamed: 0      Country  YearsCode  \
# 0           0      Ukraine       14.0
# 1           1  Netherlands       10.0
# 2           2      Ukraine       12.0
# 3           3      Ukraine        5.0
# 4           4      Ukraine       22.0
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# 4  Independent contractor, freelancer, or self-em...
#
#                               LanguageHaveWorkedWith  ConvertedCompYearly
# ...

# %%
df_clean.drop(columns =['Unnamed: 0'], inplace =True)

# %%
df_clean.shape
# Out:
# (49191, 6)

# %%
TARGET = df_clean['ConvertedCompYearly']

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 35437 non-null  str
#  1   YearsCode               43042 non-null  float64
#  2   EdLevel                 48149 non-null  str
#  3   Employment              48339 non-null  str
#  4   LanguageHaveWorkedWith  31671 non-null  str
#  5   ConvertedCompYearly     23947 non-null  float64
# dtypes: float64(2), str(4)
# memory usage: 7.2 MB

# %%
# Out:
# np.int64(1375400)
